# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\saket\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
data=pd.read_csv(r"C:\Users\saket\Desktop\DATASETS\TV_shows.csv")
data=data.set_index('Year')#setting index as year

# %%
data
# Out:
#       Unnamed: 0                            Title  Age  IMDb Rotten Tomatoes  \
# Year
# 2008           0                     Breaking Bad  18+   9.5             96%
# 2016           1                  Stranger Things  16+   8.8             93%
# 2017           2                      Money Heist  18+   8.4             91%
# 2010           3                         Sherlock  16+   9.1             78%
# 2015           4                 Better Call Saul  18+   8.7             97%
# ...          ...                              ...  ...   ...             ...
# 2018        5606  Tut's Treasures: Hidden Secrets  NaN   NaN             NaN
# 2017        5607                 Paradise Islands  NaN   NaN             NaN
# 2018        5608                      Wild Russia  NaN   NaN             NaN
# 2017        5609                      Love & Vets  NaN   NaN             NaN
# 2016        5610         United States of Animals  NaN   NaN             NaN
#
# ...

# %%
data['Netflix'].rolling(25).mean().plot()

# %%
data_imdb=data[data['IMDb']>8.5]#imdb data collected for whose IMDB rating grater than 8.5

# %%
pd.DataFrame(data[['Netflix','Prime Video','Hulu']]).plot()

# %%
data_imdb
# Out:
#       Unnamed: 0                   Title  Age  IMDb Rotten Tomatoes  Netflix  \
# Year
# 2008           0            Breaking Bad  18+   9.5             96%        1
# 2016           1         Stranger Things  16+   8.8             93%        1
# 2010           3                Sherlock  16+   9.1             78%        1
# 2015           4        Better Call Saul  18+   8.7             97%        1
# 2005           5              The Office  16+   8.9             81%        1
# ...          ...                     ...  ...   ...             ...      ...
# 2019        5455         The Mandalorian   7+   8.7             93%        0
# 2018        5461        One Strange Rock  all   8.8             83%        0
# 2019        5465  The Imagineering Story   7+   9.1            100%        0
# 2020        5499            Prop Culture   7+   8.6             NaN        0
# 2019        5600       Prairie Dog Manor  NaN   8.6             NaN        0
#
# ...

# %%
#Imdb_rotten_tomatoes_data=
data[data['IMDb']>8.5] & data[data['Rotten Tomatoes']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f1fb2d3c37a7> in <module>
#       1 #Imdb_rotten_tomatoes_data=
# ----> 2 data[data['IMDb']>8.5] & data[data['Rotten Tomatoes']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2788
#    2789         # Do we have a (boolean) 1d indexer?
# -> 2790         if com.is_bool_indexer(key):
#    2791             return self._getitem_bool_array(key)
#    2792
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     134             if not lib.is_bool_array(key):
#     135                 if isna(key).any():
# --> 136                     raise ValueError(na_msg)
#     137                 return False
#     138             return True
#
# ValueError: cannot mask with array containing NA / NaN values

# %%
a=list(data['Rotten Tomatoes'].dropna().unique())

# %%
#return float(x.strip('%'))/100
