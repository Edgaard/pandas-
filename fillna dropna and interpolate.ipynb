# %%
import pandas as pd

# %%
#----------------------To read data frame to CSV file----------------------------------------#
#my_dict={
    #'day':['1/1/17','2/1/17','3/1/17','4/1/17','5/1/17','6/2/18'],
    #'event':['Rain','Mist','Cloudy','sunny','Snow','cold'],
    #'temperature':[32,45,66,77,55,33],
    #'windspeed':[1,2,3,4,5,6],
    #'city':['Mumbai','Banglore','hyderabad','kochin','vizag','chennai']
#}
#data=pd.DataFrame(my_dict)
#data.to_csv(r'C:\Users\saket\Desktop\DATASETS\weather_data.csv',index=False

# %%
data=pd.read_csv(r'C:\Users\saket\Desktop\DATASETS\weather_data.csv',parse_dates=['day'])
data.set_index('day',inplace=True)
#data['day']=pd.to_datetime(data['day'])#<- converted to actul date using to_datetime fucntion in pandas<- alternative for conveting into actual date fucntion

# %%
#new_data=data[['temperature']].fillna(0)

# %%
#new_data.plot()

# %%
data.head(4)
# Out:
#              event  temperature  windspeed       city
# day
# 2017-01-01    Rain          NaN        1.0     Mumbai
# 2017-01-02     NaN         45.0        2.0   Banglore
# 2017-01-03  Cloudy         66.0        3.0  hyderabad
# 2017-01-04   sunny         77.0        NaN     kochin

# %%
#----------------In the particualr code we are filling the values with "0" and "No event" with all the columns----"
new_data=data.fillna({
    'temperature':0,
    'event':'No Event',
    'windspeed':0
})
#data[['temperature','windspeed']]=data[['temperature','windspeed']].fillna(0)#<- alternative for the upper code
#data[['event']]=data[['event']].fillna('No Event')

# %%
new_data_1=data.fillna(method='ffill',limit=2)#<-  ffill means carry forward  ### bfill->backward fill

# %%
new_data_3=data[['temperature']].interpolate()

# %%
new_data_3
# Out:
#             temperature
# day
# 2017-01-01          NaN
# 2017-01-02         45.0
# 2017-01-03         66.0
# 2017-01-04         77.0
# 2017-01-05         55.0
# 2017-01-06         55.0
# 2017-01-07         55.0
# 2017-01-08         57.0
# 2017-01-09         58.0
# 2017-01-10         59.0
# 2017-01-11         60.5
# 2017-01-12         62.0
# 2017-01-18         63.0
# 2017-01-19         65.0
# 2017-01-21         66.0
# 2017-01-16         67.0
# 2017-01-17         69.0
# 2017-01-18         70.0
# 2017-01-25         71.0
# 2017-01-20         73.0

# %%
import numpy as np
my_dict={
    'A':[10,20,30,40,np.NaN,50]
}
tp_data=pd.DataFrame(my_dict)

# %%
tp_data
# Out:
#       A
# 0  10.0
# 1  20.0
# 2  30.0
# 3  40.0
# 4   NaN
# 5  50.0

# %%
ip_data=tp_data.interpolate()

# %%
ip_data
# Out:
#       A
# 0  10.0
# 1  20.0
# 2  30.0
# 3  40.0
# 4  45.0
# 5  50.0

# %%
data.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-18', '2017-01-19', '2017-01-21', '2017-01-16',
#                '2017-01-17', '2017-01-18', '2017-01-25', '2017-01-20'],
#               dtype='datetime64[ns]', name='day', freq=None)

# %%
data2=data

# %%
data2[['temperature']]=data2[['temperature']].interpolate(method='time')

# %%
data2.dropna().set_index('city').plot()

# %%
data[['windspeed']].interpolate()
# Out:
#             windspeed
# day
# 2017-01-01        1.0
# 2017-01-02        2.0
# 2017-01-03        3.0
# 2017-01-04        4.0
# 2017-01-05        5.0
# 2017-01-06        6.0
# 2017-01-07        7.0
# 2017-01-08        8.0
# 2017-01-09        9.0
# 2017-01-10       10.0
# 2017-01-11       11.0
# 2017-01-12       12.0
# 2017-01-18       13.0
# 2017-01-19       14.0
# 2017-01-21       15.0
# 2017-01-16       16.0
# 2017-01-17       17.0
# 2017-01-18       18.0
# 2017-01-25       19.0
# 2017-01-20       20.0

# %%
data2.dropna(how='all')#to drop na value when all the three columns are having "NaN"
# Out:
#              event  temperature  windspeed       city
# day
# 2017-01-01    Rain          NaN        1.0     Mumbai
# 2017-01-02     NaN         45.0        2.0   Banglore
# 2017-01-03  Cloudy         66.0        3.0  hyderabad
# 2017-01-04   sunny         77.0        NaN     kochin
# 2017-01-05     NaN         55.0        5.0      vizag
# 2017-01-06     NaN         55.0        6.0    chennai
# 2017-01-07    Rain         55.0        7.0     Mumbai
# 2017-01-08    Mist         57.0        8.0   Banglore
# 2017-01-09  Cloudy         58.0        9.0  hyderabad
# 2017-01-10     NaN         59.0        NaN     kochin
# 2017-01-11    Snow         60.5        NaN      vizag
# 2017-01-12    cold         62.0       12.0    chennai
# 2017-01-18    Rain         63.0        NaN     Mumbai
# 2017-01-19    Mist         65.0       14.0   Banglore
# 2017-01-21     NaN         66.0       15.0  hyderabad
# 2017-01-16   sunny         67.0       16.0     kochin
# ...

# %%
data.dropna(thresh=1)
# Out:
#              event  temperature  windspeed       city
# day
# 2017-01-01    Rain          NaN        1.0     Mumbai
# 2017-01-02     NaN         45.0        2.0   Banglore
# 2017-01-03  Cloudy         66.0        3.0  hyderabad
# 2017-01-04   sunny         77.0        NaN     kochin
# 2017-01-05     NaN         55.0        5.0      vizag
# 2017-01-06     NaN         55.0        6.0    chennai
# 2017-01-07    Rain         55.0        7.0     Mumbai
# 2017-01-08    Mist         57.0        8.0   Banglore
# 2017-01-09  Cloudy         58.0        9.0  hyderabad
# 2017-01-10     NaN         59.0        NaN     kochin
# 2017-01-11    Snow         60.5        NaN      vizag
# 2017-01-12    cold         62.0       12.0    chennai
# 2017-01-18    Rain         63.0        NaN     Mumbai
# 2017-01-19    Mist         65.0       14.0   Banglore
# 2017-01-21     NaN         66.0       15.0  hyderabad
# 2017-01-16   sunny         67.0       16.0     kochin
# ...

# %%
#------------------------the particualtuar code is uesd for implemetning the missing data values------#
dt=pd.date_range('2017-01-01','2017-01-20')
idx=pd.DatetimeIndex(dt)
data.index=idx
#---------------------------------------the other alternative example----------------------------------#

#a=[]
#for i in range(1,21):
    #a.append('2017-1-'+str(i))
#a=20
#print('2017-01-'+str(a))
#date_dict={
    #'day':a
#}
#new_date=pd.DataFrame(date_dict)
#data_4=pd.read_csv(r'C:\Users\saket\Desktop\DATASETS\weather_data.csv')
#data_4.set_index('day',inplace=True)
#data_4.index=new_date['day']
#data_4.index=new_date['day']
