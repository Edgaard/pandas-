# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\saket\Desktop\DATASETS\us_university.csv')

# %%
data.head(2)
# Out:
#                          SCHOOL         STATE     CITY  NOC  \
# 0              Albright College  Pennsylvania  Reading    1
# 1  American Sentinel University      Colorado   Aurora    1
#
#                                              PROGRAM TYPE  \
# 0                      M.S. in Business Intelligence    M
# 1  Master of Science Business Intelligence and An...    M
#
#                           DEPARTMENT DELIVERY    DURATION         PREREQ  ...  \
# 0  Erivan K. Haub School of Business   Online  30 credits  Not Available  ...
# 1                      Not Available   Online  36 credits  Not Available  ...
#
#   RESEARCH  CITATIONS  INCOME TOTAL_SCORE NUM_STUDENTS  STUDENT_STAFF_RATIO  \
# 0      NaN        NaN     NaN         NaN          NaN                  NaN
# 1      NaN        NaN     NaN         NaN          NaN                  NaN
#
#    INTERNATIONAL_STUDENTS  F_M_RATIO  YEAR timesData
# 0                     NaN        NaN   NaN         0
# ...

# %%
state_data=data.groupby('STATE')#datasets get group by states 
state_data.get_group('Colorado').set_index('CITY')
# Out:
#                                                     SCHOOL     STATE  NOC  \
# CITY
# Aurora                        American Sentinel University  Colorado    1
# Denver                                    Aspen University  Colorado    1
# Fort Collins        Colorado State University-Fort Collins  Colorado    1
# Greenwood Village  Colorado State University-Global Campus  Colorado    1
# Colorado Springs             Colorado Technical University  Colorado    1
# Denver                                    Regis University  Colorado    1
# Boulder                     University of Colorado Boulder  Colorado    1
# Boulder                     University of Colorado Boulder  Colorado    1
# Boulder                     University of Colorado Boulder  Colorado    1
# Boulder                     University of Colorado Boulder  Colorado    1
# Boulder                     University of Colorado Boulder  Colorado    1
# Boulder                     University of Colorado Boulder  Colorado    1
# ...

# %%
new_data=pd.DataFrame()#-< this he data fram used for practicegive3n by sendtex
for states ,states_data in data.groupby('STATE'):
    if new_data.empty:
        new_data=states_data.set_index('CITY')[['STATE']].rename(columns={'STATE':states})
    else:
        new_data=new_data.join(states_data.set_index('CITY')[['STATE']].rename(columns={'STATE':states}))

# %%
new_data
# Out:
#                    Alabama Arizona Arkansas California Colorado Connecticut  \
# CITY
# Auburn University  Alabama     NaN      NaN        NaN      NaN         NaN
# Auburn University  Alabama     NaN      NaN        NaN      NaN         NaN
# Birmingham         Alabama     NaN      NaN        NaN      NaN         NaN
# Huntsville         Alabama     NaN      NaN        NaN      NaN         NaN
# Tuscaloosa         Alabama     NaN      NaN        NaN      NaN         NaN
# Tuscaloosa         Alabama     NaN      NaN        NaN      NaN         NaN
# Tuscaloosa         Alabama     NaN      NaN        NaN      NaN         NaN
# Tuscaloosa         Alabama     NaN      NaN        NaN      NaN         NaN
#
#                   District of Columbia Florida Georgia Hawaii  ... Oklahoma  \
# CITY                                                           ...
# Auburn University                  NaN     NaN     NaN    NaN  ...      NaN
# ...

# %%
n_data=pd.DataFrame()#<- data set created by own
state_data=data.groupby('STATE')#datasets get group by sta

# %%
for states, states_data in state_data:
    if n_data.empty:
        n_data=state_data.get_group(states).set_index('CITY')[['STATE']].rename(columns={'STATE':states})
    else:
          n_data=n_data.join(state_data.get_group(states).set_index('CITY')[['STATE']].rename(columns={'STATE':states}))

# %%
n_data.head(5)
# Out:
#                    Alabama Arizona Arkansas California Colorado Connecticut  \
# CITY
# Auburn University  Alabama     NaN      NaN        NaN      NaN         NaN
# Auburn University  Alabama     NaN      NaN        NaN      NaN         NaN
# Birmingham         Alabama     NaN      NaN        NaN      NaN         NaN
# Huntsville         Alabama     NaN      NaN        NaN      NaN         NaN
# Tuscaloosa         Alabama     NaN      NaN        NaN      NaN         NaN
#
#                   District of Columbia Florida Georgia Hawaii  ... Oklahoma  \
# CITY                                                           ...
# Auburn University                  NaN     NaN     NaN    NaN  ...      NaN
# Auburn University                  NaN     NaN     NaN    NaN  ...      NaN
# Birmingham                         NaN     NaN     NaN    NaN  ...      NaN
# Huntsville                         NaN     NaN     NaN    NaN  ...      NaN
# ...

# %%
n_data.describe()#<- it gives the basic Stats for the data
# Out:
#         Alabama Arizona Arkansas California Colorado Connecticut  \
# count         8       0        0          0        0           0
# unique        1       0        0          0        0           0
# top     Alabama     NaN      NaN        NaN      NaN         NaN
# freq          8     NaN      NaN        NaN      NaN         NaN
#
#        District of Columbia Florida Georgia Hawaii  ... Oklahoma Pennsylvania  \
# count                     0       0       0      0  ...        0            0
# unique                    0       0       0      0  ...        0            0
# top                     NaN     NaN     NaN    NaN  ...      NaN          NaN
# freq                    NaN     NaN     NaN    NaN  ...      NaN          NaN
#
#        South Carolina South Dakota Tennessee Texas Virginia Washington  \
# count               0            0         0     0        0          0
# unique              0            0         0     0        0          0
# ...

# %%
import numpy as np
n_data=n_data.replace(0,np.NaN).dropna(axis=1)

# %%
n_data
# Out:
#                    Alabama
# CITY
# Auburn University  Alabama
# Auburn University  Alabama
# Birmingham         Alabama
# Huntsville         Alabama
# Tuscaloosa         Alabama
# Tuscaloosa         Alabama
# Tuscaloosa         Alabama
# Tuscaloosa         Alabama

# %%
n_data.columns
# Out:
# Index(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Missouri', 'Montana', 'Nebraska', 'New Hampshire', 'New Jersey',
#        'New Mexico', 'New York', 'North Carolina', 'Ohio', 'Oklahoma',
#        'Pennsylvania', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin'],
#       dtype='object')

# %%
#n_data.isnull()

# %%
#_data['Arizona'].isnull().values.any()<- for checking the values
